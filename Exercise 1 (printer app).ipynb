# %%
print("Printer App")
name = "Valtteri Ahde"
type(name)
print("This app is made by: " + name)
# Out:
# Printer App
# This app is made by: Valtteri Ahde

# %%
number1 = 5
number2 = 3
type(number1)
type(number2)
print("the value of number1 is:",number1)
number1 = 500
print("the value of number1 is:",number1)
print("the value of number2 is:",number2)
print("-----------------------------")
print("multiplication")
print("")
multiplication = number1 * number2
type(multiplication)
print("number1 is",number1)
print("number2 is",number2)
print(number1,"*",number2,"=",multiplication)
number1 = 10
number2 = 5
multiplication = number1 * number2
print("\nnumber1 is",number1)
print("number2 is",number2)
print(number1,"*",number2,"=",multiplication)
print("-----------------------------")
print("division")
print("")
division = number1 / number2
type(division)
print("number1 is",number1)
print("number2 is",number2)
print(number1,"/",number2,"=",division)
number1 = 100
number2 = 2
division = number1 / number2
print("")
print("number1 is",number1)
print("number2 is",number2)
print(number1,"/",number2,"=",division)
print("-----------------------------")
print("substraction")
print("")
substraction = number1 - number2
type(substraction)
print("number1 is",number1)
print("number2 is",number2)
print(number1,"-",number2,"=",substraction)
number1 = 1000
number2 = 50
substraction = number1 - number2
print("")
print("number1 is",number1)
print("number2 is",number2)
print(number1,"-",number2,"=",substraction)
# Out:
# the value of number1 is: 5
# the value of number1 is: 500
# the value of number2 is: 3
# -----------------------------
# multiplication
#
# number1 is 500
# number2 is 3
# 500 * 3 = 1500
#
# number1 is 10
# number2 is 5
# 10 * 5 = 50
# -----------------------------
# division
#
# number1 is 10
# number2 is 5
# 10 / 5 = 2.0
#
# number1 is 100
# number2 is 2
# 100 / 2 = 50.0
# -----------------------------
# substraction
#
# number1 is 100
# number2 is 2
# 100 - 2 = 98
#
# number1 is 1000
# number2 is 50
# 1000 - 50 = 950
